# %%
# Author: Willian M. Braga 
# Análises diárias dos indices de fechamento Ibovespa 


import pandas as pd
import datetime

dataset = pd.read_csv('/home/will/Documentos/SIAD/datasets/ipeadata_ibovespa_fechamento.csv', sep=",")
dataset
# Out:
#              Data  \
# 0      02/01/1900
# 1      03/01/1900
# 2      04/01/1900
# 3      05/01/1900
# 4      06/01/1900
# ...           ...
# 44018  09/07/2020
# 44019  10/07/2020
# 44020  11/07/2020
# 44021  12/07/2020
# 44022  13/07/2020
#
#        Índice de ações - Ibovespa - fechamento - - - Bolsa de Valores- Mercadorias e Futuros (BM&FBovespa) - GM366_IBVSP366  \
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
# ...                                                  ...
# 44018                                            99160.0
# 44019                                           100032.0
# 44020                                                NaN
# 44021                                                NaN
# 44022                                            98697.0
#
#        Estados Unidos - Índice de ações - Dow Jones - fechamento - - - Valor Econômico - GM366_DOW366  \
# 0                                                  68.13
# 1                                                  66.61
# 2                                                  67.15
# 3                                                  66.71
# 4                                                  66.02
# ...                                                  ...
# 44018                                           25706.09
# 44019                                           26075.30
# 44020                                                NaN
# 44021                                                NaN
# 44022                                           26085.80
#
#        Unnamed: 3
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
# ...           ...
# 44018         NaN
# 44019         NaN
# 44020         NaN
# 44021         NaN
# 44022         NaN
#
# [44023 rows x 4 columns]

# %%
# Preparação dos dados
dataset.columns = ['data_fato','indice_ibovespa','indice_dow_jones', '?']  
dataset.drop('?', inplace=True, axis=1)  
dataset = dataset.dropna()
dataset
# Out:
#         data_fato  indice_ibovespa  indice_dow_jones
# 34517  05/07/1994           3564.3       3652.479645
# 34518  06/07/1994           3753.5       3674.494236
# 34519  07/07/1994           3904.9       3688.415227
# 34520  08/07/1994           4051.9       3709.134842
# 34523  11/07/1994           4010.8       3702.983707
# ...           ...              ...               ...
# 44016  07/07/2020          97761.0      25890.180000
# 44017  08/07/2020          99770.0      26067.280000
# 44018  09/07/2020          99160.0      25706.090000
# 44019  10/07/2020         100032.0      26075.300000
# 44022  13/07/2020          98697.0      26085.800000
#
# [6252 rows x 3 columns]

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(25,10)})
dataset.set_index('data_fato').plot(y=['indice_ibovespa', 'indice_dow_jones'] ,fontsize=20,linewidth=1 , logy=True)

# %%
# Restringir periodo entre 02/01/2010 - 02/01/2020
dataset['data_fato'] = pd.to_datetime(dataset['data_fato'], format='%d/%m/%Y')
periodo = (dataset['data_fato']>'01/02/2010') & (dataset['data_fato'] < '01/03/2020')
dataset_2 = dataset[periodo].copy()
dataset_2
# Out:
# /home/will/.local/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#        data_fato  indice_ibovespa  indice_dow_jones
# 40179 2010-01-04          70045.0          10584.00
# 40180 2010-01-05          70239.0          10572.00
# 40181 2010-01-06          70729.0          10573.70
# 40182 2010-01-07          70451.0          10606.90
# 40183 2010-01-08          70262.0          10618.20
# ...          ...              ...               ...
# 43819 2019-12-23         115863.0          28551.53
# 43822 2019-12-26         117203.0          28621.39
# 43823 2019-12-27         116534.0          28645.26
# 43826 2019-12-30         115964.0          28462.14
# 43829 2020-01-02         118573.0          28868.80
#
# [2361 rows x 3 columns]

# %%
sns.set(rc={'figure.figsize':(20,10)})
dataset_2.set_index('data_fato').sort_index().plot(y=['indice_ibovespa', 'indice_dow_jones'],logy=True ,fontsize=20,linewidth=1)

# %%
dataset_2.corr(method='pearson').style.background_gradient()
# Com base na correlação podemos concluir que...
# Out:
# <style  type="text/css" >
#     #T_8fbc50b2_c766_11ea_9f6c_68a3c4f5fe54row0_col0 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }    #T_8fbc50b2_c766_11ea_9f6c_68a3c4f5fe54row0_col1 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_8fbc50b2_c766_11ea_9f6c_68a3c4f5fe54row1_col0 {
#             background-color:  #fff7fb;
#             color:  #000000;
#         }    #T_8fbc50b2_c766_11ea_9f6c_68a3c4f5fe54row1_col1 {
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }</style><table id="T_8fbc50b2_c766_11ea_9f6c_68a3c4f5fe54" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >indice_ibovespa</th>        <th class="col_heading level0 col1" >indice_dow_jones</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8fbc50b2_c766_11ea_9f6c_68a3c4f5fe54level0_row0" class="row_heading level0 row0" >indice_ibovespa</th>
#                         <td id="T_8fbc50b2_c766_11ea_9f6c_68a3c4f5fe54row0_col0" class="data row0 col0" >1.000000</td>
#                         <td id="T_8fbc50b2_c766_11ea_9f6c_68a3c4f5fe54row0_col1" class="data row0 col1" >0.657795</td>
#             </tr>
#             <tr>
#                         <th id="T_8fbc50b2_c766_11ea_9f6c_68a3c4f5fe54level0_row1" class="row_heading level0 row1" >indice_dow_jones</th>
#                         <td id="T_8fbc50b2_c766_11ea_9f6c_68a3c4f5fe54row1_col0" class="data row1 col0" >0.657795</td>
#                         <td id="T_8fbc50b2_c766_11ea_9f6c_68a3c4f5fe54row1_col1" class="data row1 col1" >1.000000</td>
#             </tr>
#     </tbody></table>

# %%
dataset_2.set_index('data_fato').sort_index()
# Out:
#             indice_ibovespa  indice_dow_jones
# data_fato
# 2010-01-04          70045.0          10584.00
# 2010-01-05          70239.0          10572.00
# 2010-01-06          70729.0          10573.70
# 2010-01-07          70451.0          10606.90
# 2010-01-08          70262.0          10618.20
# ...                     ...               ...
# 2019-12-23         115863.0          28551.53
# 2019-12-26         117203.0          28621.39
# 2019-12-27         116534.0          28645.26
# 2019-12-30         115964.0          28462.14
# 2020-01-02         118573.0          28868.80
#
# [2361 rows x 2 columns]

# %%
from sklearn.preprocessing import StandardScaler

ibovespa_norm = dataset_2["indice_ibovespa"].values.copy()
ibovespa_norm.shape = (len(ibovespa_norm), 1)

scaler = StandardScaler()
ibovespa_norm = scaler.fit_transform(ibovespa_norm)
dataset_2["indice_ibovespa_norm"] = ibovespa_norm

dow_jones_norm = dataset_2["indice_dow_jones"].values.copy()
dow_jones_norm.shape = (len(dow_jones_norm), 1)

scaler = StandardScaler()
dow_jones_norm = scaler.fit_transform(dow_jones_norm)
dataset_2["indice_dj_norm"] = dow_jones_norm
dataset_2.head(10)
# Out:
#        data_fato  indice_ibovespa  indice_dow_jones  indice_ibovespa_norm  \
# 40179 2010-01-04          70045.0           10584.0              0.314502
# 40180 2010-01-05          70239.0           10572.0              0.326730
# 40181 2010-01-06          70729.0           10573.7              0.357615
# 40182 2010-01-07          70451.0           10606.9              0.340093
# 40183 2010-01-08          70262.0           10618.2              0.328180
# 40186 2010-01-11          70433.0           10664.0              0.338958
# 40187 2010-01-12          70076.0           10627.0              0.316456
# 40188 2010-01-13          70385.0           10681.0              0.335933
# 40189 2010-01-14          69801.0           10711.0              0.299122
# 40190 2010-01-15          68978.0           10610.0              0.247247
#
#        indice_dj_norm
# 40179       -1.357235
# 40180       -1.359548
# 40181       -1.359220
# 40182       -1.352821
# 40183       -1.350643
# 40186       -1.341815
# 40187       -1.348947
# 40188       -1.338538
# 40189       -1.332756
# 40190       -1.352223

# %%
df_ibovespa = pd.DataFrame()
window_size = 17
for i in range(0, window_size + 1):
    df_ibovespa["E{}".format(i)] = dataset_2["indice_ibovespa_norm"].shift(-i)
df_ibovespa = df_ibovespa.iloc[:-window_size]
df_ibovespa
# Out:
#              E0        E1        E2        E3        E4        E5        E6  \
# 40179  0.314502  0.326730  0.357615  0.340093  0.328180  0.338958  0.316456
#         3.24477801e+00, 3.20884999e+00, 3.37329945e+00]])

# %%
X = arr[:, :-1]
target = arr[:, -1]
print(X)
print(target)
# Out:
# [[3.14501807e-01 3.26729938e-01 3.57615424e-01 ... 7.34059248e-02
#   2.95359290e-02 9.19581167e-04]
#  [3.26729938e-01 3.57615424e-01 3.40092638e-01 ... 2.95359290e-02
#   9.19581167e-04 3.35699516e-02]
#  [3.57615424e-01 3.40092638e-01 3.28179665e-01 ... 9.19581167e-04
#   3.35699516e-02 2.18460734e-02]
#  ...
#  [2.77374284e+00 2.77021307e+00 2.85190203e+00 ... 3.15571435e+00
#   3.20248380e+00 3.28694615e+00]
#  [2.77021307e+00 2.85190203e+00 2.87213517e+00 ... 3.20248380e+00
#   3.28694615e+00 3.24477801e+00]
#  [2.85190203e+00 2.87213517e+00 2.90390310e+00 ... 3.28694615e+00
#   3.24477801e+00 3.20884999e+00]]
# [0.03356995 0.02184607 0.09559305 ... 3.24477801 3.20884999 3.37329945]

# %%
from sklearn.neural_network import MLPRegressor
from sklearn.model_selection import cross_val_predict
from sklearn import metrics

mlp = MLPRegressor(hidden_layer_sizes=(50,100,), activation="logistic", max_iter=1000, solver="sgd", verbose=True)
full_predict = cross_val_predict(mlp, X, target, cv=10)
print("Mean Squared Error: %s" %(metrics.mean_squared_error(target, full_predict)))
# Out:
# Iteration 1, loss = 0.54367724
# Iteration 2, loss = 0.53616070
# Iteration 3, loss = 0.53070370
# Iteration 4, loss = 0.52793202
# Iteration 5, loss = 0.52295380
# Iteration 6, loss = 0.51847864
# Iteration 7, loss = 0.51397800
# Iteration 8, loss = 0.50961237
# Iteration 9, loss = 0.50515454
# Iteration 10, loss = 0.50045178
# Iteration 11, loss = 0.49561598
# Iteration 12, loss = 0.49012025
# Iteration 13, loss = 0.48470104
# Iteration 14, loss = 0.47918213
# Iteration 15, loss = 0.47313983
# Iteration 16, loss = 0.46715592
# Iteration 17, loss = 0.46117395
# Iteration 18, loss = 0.45435103
# Iteration 19, loss = 0.44747067
# Iteration 20, loss = 0.44016286
# Iteration 21, loss = 0.43256737
# Iteration 22, loss = 0.42469564
# Iteration 23, loss = 0.41638270
# Iteration 24, loss = 0.40786154
# Iteration 25, loss = 0.39887836
# Iteration 26, loss = 0.38961932
# Iteration 27, loss = 0.37988271
# Iteration 28, loss = 0.36963646
# Iteration 29, loss = 0.35921948
# Iteration 30, loss = 0.34832150
# Iteration 31, loss = 0.33739956
# Iteration 32, loss = 0.32603322
# Iteration 33, loss = 0.31371514
# Iteration 34, loss = 0.30181719
# Iteration 35, loss = 0.28922766
# Iteration 36, loss = 0.27656745
# Iteration 37, loss = 0.26355869
# Iteration 38, loss = 0.25078544
# Iteration 39, loss = 0.23789850
# Iteration 40, loss = 0.22455027
# Iteration 41, loss = 0.21166838
# Iteration 42, loss = 0.19877146
# Iteration 43, loss = 0.18607273
# Iteration 44, loss = 0.17373419
# Iteration 45, loss = 0.16134351
# Iteration 46, loss = 0.14967012
# Iteration 47, loss = 0.13826441
# Iteration 48, loss = 0.12733048
# Iteration 49, loss = 0.11689137
# Iteration 25, loss = 0.40410893
# Iteration 26, loss = 0.39540525
# Iteration 27, loss = 0.38653380
# Iteration 28, loss = 0.37740742
# Iteration 29, loss = 0.36727005
# Iteration 30, loss = 0.35726850
# Iteration 31, loss = 0.34747506
# Iteration 32, loss = 0.33656159
# Iteration 33, loss = 0.32620023
# Iteration 34, loss = 0.31520942
# Iteration 35, loss = 0.30396398
# Iteration 36, loss = 0.29248998
# Iteration 37, loss = 0.28084974
# Iteration 38, loss = 0.26939366
# Iteration 39, loss = 0.25739100
# Iteration 40, loss = 0.24575022
# Iteration 41, loss = 0.23388298
# Iteration 42, loss = 0.22178069
# Iteration 43, loss = 0.20974938
# Iteration 44, loss = 0.19808214
# Iteration 45, loss = 0.18654289
# Iteration 46, loss = 0.17505928
# Iteration 47, loss = 0.16409754
# Iteration 48, loss = 0.15345355
# Iteration 49, loss = 0.14301093
# Iteration 50, loss = 0.13298452
# Iteration 51, loss = 0.12325647
# Iteration 52, loss = 0.11423154
# Iteration 53, loss = 0.10567128
# Iteration 54, loss = 0.09755306
# Iteration 55, loss = 0.09003459
# Iteration 56, loss = 0.08308528
# Iteration 57, loss = 0.07657830
# Iteration 58, loss = 0.07054396
# Iteration 59, loss = 0.06523000
# Iteration 60, loss = 0.06024387
# Iteration 61, loss = 0.05583028
# Iteration 62, loss = 0.05173751
# Iteration 63, loss = 0.04816383
# Iteration 64, loss = 0.04488229

# %%
print(len(full_predict))
print(len(dataset_2["indice_ibovespa_norm"]))

# %%
import numpy as np

values_to_add = list()
for i in range(0, window_size):
    values_to_add.append(float("NaN"))
full_predict = np.insert(full_predict, 0, values_to_add)
full_predict.shape = (len(full_predict), 1)
full_predict.shape

# %%
dataset_2["predict_ibovespa"] = full_predict
dataset_2

# %%
dataset_2.set_index('data_fato').plot(y=["indice_ibovespa_norm", "predict_ibovespa"] ,fontsize=20,linewidth=3)

# %%
# Indice Dow Jones
df_jones = pd.DataFrame()
window_size = 17
for i in range(0, window_size + 1):
    df_jones["E{}".format(i)] = dataset_2["indice_dj_norm"].shift(-i)
df_jones = df_jones.iloc[:-window_size]
df_jones

# %%
arr_dj = df_jones.values
arr_dj

# %%
X_dj = arr_dj[:, :-1]
target_dj = arr_dj[:, -1]
print(X_dj)
print(target_dj)

# %%
mlp = MLPRegressor(hidden_layer_sizes=(50,100,), activation="logistic", max_iter=1000, solver="sgd", verbose=True)
full_predict_dj = cross_val_predict(mlp, X_dj, target_dj, cv=10)
print("Mean Squared Error: %s" %(metrics.mean_squared_error(target_dj, full_predict_dj)))

# %%
print(len(full_predict_dj))
print(len(dataset_2["indice_dj_norm"]))

# %%
values_to_add_dj = list()
for i in range(0, window_size):
    values_to_add_dj.append(float("NaN"))
full_predict_dj = np.insert(full_predict_dj, 0, values_to_add_dj)
full_predict_dj.shape = (len(full_predict_dj), 1)
full_predict_dj.shape

# %%
dataset_2["predict_dj"] = full_predict_dj
dataset_2

# %%
dataset_2.set_index('data_fato').plot(y=["indice_dj_norm", "predict_dj"] ,fontsize=20,linewidth=3)
